# %%
import pandas as pd

# %%
movies=pd.read_csv('imdb_1000.csv')
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies['title']
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
movies['title'].sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
movies['title'].sort_values(ascending=False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
movies.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movies['title'].sort_values(na_position='first')
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
movies['content_rating'].sort_values(na_position='first') # by defualt it is last
# Out:
# 187         NaN
# 649         NaN
# 936         NaN
# 253    APPROVED
# 52     APPROVED
#          ...
# 802     UNRATED
# 913           X
# 387           X
# 86            X
# 486           X
# Name: content_rating, Length: 979, dtype: object

# %%
movies.set_index('title')
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
movies.set_index('title', inplace=True)

# %%
movies
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
movies['star_rating']
# Out:
# title
# The Shawshank Redemption                           9.3
# The Godfather                                      9.2
# The Godfather: Part II                             9.1
# The Dark Knight                                    9.0
# Pulp Fiction                                       8.9
#                                                   ...
# Tootsie                                            7.4
# Back to the Future Part III                        7.4
# Master and Commander: The Far Side of the World    7.4
# Poltergeist                                        7.4
# Wall Street                                        7.4
# Name: star_rating, Length: 979, dtype: float64

# %%
movies['star_rating'].sort_values()
# Out:
# title
# Wall Street                                        7.4
# Poltergeist                                        7.4
# Master and Commander: The Far Side of the World    7.4
# Back to the Future Part III                        7.4
# Tootsie                                            7.4
#                                                   ...
# Pulp Fiction                                       8.9
# The Dark Knight                                    9.0
# The Godfather: Part II                             9.1
# The Godfather                                      9.2
# The Shawshank Redemption                           9.3
# Name: star_rating, Length: 979, dtype: float64

# %%
movies['star_rating'].sort_index()
# Out:
# title
# (500) Days of Summer     7.8
# 12 Angry Men             8.9
# 12 Years a Slave         8.1
# 127 Hours                7.6
# 2001: A Space Odyssey    8.3
#                         ...
# Zero Dark Thirty         7.4
# Zodiac                   7.7
# Zombieland               7.7
# Zulu                     7.8
# [Rec]                    7.5
# Name: star_rating, Length: 979, dtype: float64

# %%
movies.set_index('content_rating')
# Out:
#                 star_rating      genre  duration  \
# content_rating
# R                       9.3      Crime       142
# R                       9.2      Crime       175
# R                       9.1      Crime       200
# PG-13                   9.0     Action       152
# R                       8.9      Crime       154
# ...                     ...        ...       ...
# PG                      7.4     Comedy       116
# PG                      7.4  Adventure       118
# PG-13                   7.4     Action       138
# PG                      7.4     Horror       114
# R                       7.4      Crime       126
#
#                                                       actors_list
# content_rating
# R               [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# R                 [u'Marlon Brando', u'Al Pacino', u'James Caan']
# R               [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# PG-13           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# ...

# %%
movies.reset_index(inplace=True)

# %%
movies
# Out:
#                                                title  star_rating  \
# 0                           The Shawshank Redemption          9.3
# 1                                      The Godfather          9.2
# 2                             The Godfather: Part II          9.1
# 3                                    The Dark Knight          9.0
# 4                                       Pulp Fiction          8.9
# ..                                               ...          ...
# 974                                          Tootsie          7.4
# 975                      Back to the Future Part III          7.4
# 976  Master and Commander: The Far Side of the World          7.4
# 977                                      Poltergeist          7.4
# 978                                      Wall Street          7.4
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.sort_values(by='star_rating')
# Out:
#                                                title  star_rating  \
# 978                                      Wall Street          7.4
# 977                                      Poltergeist          7.4
# 976  Master and Commander: The Far Side of the World          7.4
# 975                      Back to the Future Part III          7.4
# 974                                          Tootsie          7.4
# ..                                               ...          ...
# 4                                       Pulp Fiction          8.9
# 3                                    The Dark Knight          9.0
# 2                             The Godfather: Part II          9.1
# 1                                      The Godfather          9.2
# 0                           The Shawshank Redemption          9.3
#
#     content_rating      genre  duration  \
# 978              R      Crime       126
# 977             PG     Horror       114
# 976          PG-13     Action       138
# ...

# %%
movies.sort_values(by=['star_rating', 'duration'])
# Out:
#                                              title  star_rating  \
# 938                            Alice in Wonderland          7.4
# 948                                     Frances Ha          7.4
# 966                             The Simpsons Movie          7.4
# 947                                     Eraserhead          7.4
# 971                             Death at a Funeral          7.4
# ..                                             ...          ...
# 7    The Lord of the Rings: The Return of the King          8.9
# 3                                  The Dark Knight          9.0
# 2                           The Godfather: Part II          9.1
# 1                                    The Godfather          9.2
# 0                         The Shawshank Redemption          9.3
#
#     content_rating      genre  duration  \
# 938              G  Animation        75
# 948              R     Comedy        86
# 966          PG-13  Animation        87
# ...

# %%
movies.sort_values(by=['star_rating', 'duration'], na_position='first')
# Out:
#                                              title  star_rating  \
# 938                            Alice in Wonderland          7.4
# 948                                     Frances Ha          7.4
# 966                             The Simpsons Movie          7.4
# 947                                     Eraserhead          7.4
# 971                             Death at a Funeral          7.4
# ..                                             ...          ...
# 7    The Lord of the Rings: The Return of the King          8.9
# 3                                  The Dark Knight          9.0
# 2                           The Godfather: Part II          9.1
# 1                                    The Godfather          9.2
# 0                         The Shawshank Redemption          9.3
#
#     content_rating      genre  duration  \
# 938              G  Animation        75
# 948              R     Comedy        86
# 966          PG-13  Animation        87
# ...

# %%
def movie_len(title):
    return title.str.len()

# %%
movies.sort_values(by='title', key=movie_len )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 movies.sort_values(by='title', key=movie_len )
#
# NameError: name 'movie_len' is not defined
